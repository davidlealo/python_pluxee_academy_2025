# %% [markdown]
# <a href="https://colab.research.google.com/github/davidlealo/python_pluxee_academy_2025/blob/main/prueba_API%60s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lo primero es instalar la librería

# !pip install openai

# %%
# Lo segundo es invocar la librería que vamos a usar y la función en específico
from openai import OpenAI

# %%
# Revisando el github de openai para Python https://github.com/openai/openai-python

# %%
import os

# %%
# Instancia la función de la librería con api_key

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# %%
# Instalar versión clásica si es necesario
# !pip install openai --upgrade

import openai
import os
from getpass import getpass

# Establecer la clave como variable de entorno
os.environ["OPENAI_API_KEY"] = getpass("Introduce tu clave secreta de OpenAI: ")

# Asignar api_key directamente
openai.api_key = os.environ["OPENAI_API_KEY"]
# Out:
# ...
# Introduce tu clave secreta de OpenAI: ··········

# %%
# Hacer la consulta

response = client.responses.create(
    model="gpt-4.1-nano",
    input="Dame tres ideas de emprendimiento digital en Chile."
)

print(response.output_text)
# Out:
# ¡Por supuesto! Aquí tienes tres ideas de emprendimiento digital que podrían ser viables y relevantes en Chile:
#
# 1. **Plataforma de Turismo Sustentable y Experiencias Locales**
#    Aprovechando la creciente tendencia del turismo ecológico y responsable, puedes crear una plataforma que conecte a turistas con experiencias auténticas en comunas y regiones menos exploradas de Chile. La plataforma puede incluir reservaciones para tours, hospedajes ecológicos y actividades culturales, promoviendo la economía local y el turismo sostenible.
#
# 2. **Marketplace de Productos Artesanales y Locales**
#    Desarrolla un marketplace digital dedicado a la venta de productos artesanales chilenos, como textiles, cerámica, vinos, gourmet y otros productos típicos. Este tipo de negocio apoya a los artesanos locales y permite que sus productos lleguen a un público nacional e internacional, aprovechando el auge del comercio electrónico y la valoración de productos autóctonos.
#
# ...

# %%
input_prompt = input("Escribe lo que quieres preguntar ")

response = client.responses.create(
    model="gpt-4.1-nano",
    input=input_prompt
)

print(response.output_text)
# Out:
# Escribe lo que quieres preguntar como le gusta la piña a la tía?
# ¡Hola! La frase "¿Cómo le gusta la piña a la tía?" puede interpretarse de diferentes maneras, dependiendo del contexto. Podría estar preguntando por la forma en que la tía prefiere la piña, como en qué presentación o preparación le gusta más (fresca, en jugo, en postres, etc.).
#
# ¿Podrías aclarar un poco más a qué te refieres o darme más detalles? ¡Estaré encantado de ayudarte!

# %% [markdown]
# ## Ejemplo de uso con Pandas

# %%
# Importar librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://raw.githubusercontent.com/davidlealo/tallermodelossupervisados/refs/heads/main/data/Lluvia_full.csv
# Out:
# --2025-05-08 23:08:09--  https://raw.githubusercontent.com/davidlealo/tallermodelossupervisados/refs/heads/main/data/Lluvia_full.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5978975 (5.7M) [text/plain]
# Saving to: ‘Lluvia_full.csv’
#
# Lluvia_full.csv     100%[===================>]   5.70M  17.1MB/s    in 0.3s
#
# 2025-05-08 23:08:10 (17.1 MB/s) - ‘Lluvia_full.csv’ saved [5978975/5978975]

# %%
# Cargar base de datos lluvia_full.csv
df = pd.read_csv('Lluvia_full.csv', sep=',')

# %%
df
# Out:
#        MinTemp  MaxTemp  Lluvia  Evaporacion   Sol  VelRafaga  Vel9am  Vel3pm  \
# 0          7.6     19.3     0.0          3.4   9.4       35.0    13.0    13.0
# 1          6.8     19.5     0.0          3.4   9.4       46.0    19.0    28.0
# 2          5.5     13.9     0.0          2.8   3.8       44.0    26.0    13.0
# 3          8.6     14.3     0.0          2.8   3.8       35.0    13.0    17.0
# 4          7.9     13.0     0.0          2.8   3.8       39.0    15.0    17.0
# ...        ...      ...     ...          ...   ...        ...     ...     ...
# 56415      7.6     16.1     2.8          5.6  10.6       50.0    20.0    28.0
# 56416     13.3     15.5    39.8          7.2   9.1       54.0    30.0    24.0
# 56417     13.7     23.4     3.6          5.8   3.3       85.0     6.0     6.0
# 56418     14.0     26.9     3.6          4.4   9.7       39.0     4.0    17.0
# 56419      8.0     24.3     0.0          3.4   6.3       30.0     6.0    20.0
#
# ...

# %%
input_prompt = input("Escribe lo que quieres preguntar ")

response = client.responses.create(
    model="gpt-4.1-nano",
    input=input_prompt + df
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ac85006cb295> in <cell line: 0>()
# ----> 1 input = input("Escribe lo que quieres preguntar ")
#       2
#       3 response = client.responses.create(
#       4     model="gpt-4.1-nano",
#       5     input=input + df
#
# TypeError: 'str' object is not callable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56420 entries, 0 to 56419
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MinTemp      56420 non-null  float64
#  1   MaxTemp      56420 non-null  float64
#  2   Lluvia       56420 non-null  float64
#  3   Evaporacion  56420 non-null  float64
#  4   Sol          56420 non-null  float64
#  5   VelRafaga    56420 non-null  float64
#  6   Vel9am       56420 non-null  float64
#  7   Vel3pm       56420 non-null  float64
#  8   Hum9am       56420 non-null  float64
#  9   Hum3pm       56420 non-null  float64
#  10  Pres9am      56420 non-null  float64
#  11  Pre3pm       56420 non-null  float64
#  12  Nub9am       56420 non-null  float64
#  13  Nub3pm       56420 non-null  float64
#  14  Temp9am      56420 non-null  float64
#  15  Temp3pm      56420 non-null  float64
#  16  LluviaHoy    56420 non-null  object
#  17  LluviaMan    56420 non-null  object
# ...

# %%
# Solución de Gemini pero el mensaje es muy grande

# Use a different variable name, for instance 'user_input'
user_input = input("Escribe lo que quieres preguntar ")

response = client.responses.create(
    model="gpt-4.1-nano",
    input=user_input + df.to_string() # Convert the DataFrame to string
)

print(response.output_text)
# Out:
# Escribe lo que quieres preguntar Como puedo saber si mañana llueve?
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# <ipython-input-7-7c62951513e5> in <cell line: 0>()
#       4 user_input = input("Escribe lo que quieres preguntar ")
#       5
# ----> 6 response = client.responses.create(
#       7     model="gpt-4.1-nano",
#       8     input=user_input + df.to_string() # Convert the DataFrame to string
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                         msg = f"Missing required argument: {quote(missing[0])}"
#     286                 raise TypeError(msg)
# --> 287             return func(*args, **kwargs)
#     288
#     289         return wrapper  # type: ignore
#
# ...

# %%
# Solcuión de Chat GPT - OPENAI

import pandas as pd

# Supongamos que ya tienes un DataFrame llamado df
# df = pd.read_csv("tu_archivo.csv")

# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.head(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = input("Escribe lo que quieres preguntar: ")

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Escribe lo que quieres preguntar: como puedo saber si mañana llueve?
# Las predicciones del tiempo no pueden hacerse solo con datos pasados. Necesita datos futuros previstos, como los proporcionados por las organizaciones meteorológicas o las aplicaciones de predicción del tiempo, que utilizan modelos detallados y datos en vivo para hacer predicciones.
#
# Sin embargo, este es un proceso para gererar sus propias predicciones con los datos historicos:
#
# 1. Analizar y visualizar los datos: Utilice herramientas de análisis de datos para explorar las relaciones en su conjunto de datos.
#
# 2. Preprocesar los datos: Limpiar los datos y tratar los valores faltantes, ruidosos o inconsistentes.
#
# 3. Elegir un modelo: De acuerdo con la naturaleza de sus datos, puede elegir un modelo de regresión lineal, una máquina de vectores de soporte, una red neuronal, etc.
#
# ...

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = input("Escribe lo que quieres preguntar: ")

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Escribe lo que quieres preguntar: SEgún los datos, es más probable que llueva en primavera?
# Basándome en los datos presentados, parece que es más probable que llueva en primavera. De las 10 observaciones presentadas, 6 de ellas registraron lluvia (66% de las observaciones). Sin embargo, esto es solo una muestra pequeña y los resultados pueden variar con un conjunto de datos más grande. También es importante tener en cuenta que la probabilidad de lluvia puede variar enormemente dependiendo de la ubicación geográfica específica.

# %%
df_text_display = df.tail(10)
df_text_display
# Out:
#        MinTemp  MaxTemp  Lluvia  Evaporacion   Sol  VelRafaga  Vel9am  Vel3pm  \
# 56410      8.4     22.8    16.2          5.4   7.7       31.0     7.0     6.0
# 56411      8.8     19.5     0.0          4.0   4.1       48.0    19.0    17.0
# 56412      8.3     17.0     0.0          5.6   4.6       41.0    11.0    24.0
# 56413      6.1     18.2     0.2          4.2   8.4       43.0    19.0    26.0
# 56414      6.2     16.9     0.0          5.8   8.2       44.0    20.0    24.0
# 56415      7.6     16.1     2.8          5.6  10.6       50.0    20.0    28.0
# 56416     13.3     15.5    39.8          7.2   9.1       54.0    30.0    24.0
# 56417     13.7     23.4     3.6          5.8   3.3       85.0     6.0     6.0
# 56418     14.0     26.9     3.6          4.4   9.7       39.0     4.0    17.0
# 56419      8.0     24.3     0.0          3.4   6.3       30.0     6.0    20.0
#
#        Hum9am  Hum3pm  Pres9am  Pre3pm  Nub9am  Nub3pm  Temp9am  Temp3pm  \
# ...

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = "SEgún los datos, es más probable que llueva en primavera?"

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4.1-nano",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Con base en los datos proporcionados, analizaremos si es más probable que llueva durante la primavera.
#
# Observaciones clave:
#
# 1. Porcentaje de días con lluvia en primavera:
#    - De los 10 registros, 6 indican que hubo lluvia ese día (Lluvia = Yes).
#    - Esto corresponde a un 60% de días lluviosos en primavera, lo cual es relativamente alto y sugiere una probabilidad significativa de lluvia en esta estación.
#
# 2. Cantidad media y distribución de lluvias:
#    - Algunos días muestran lluvias intensas (por ejemplo, con porcentajes cercanos al 40%) y otros días con lluvia ligera o moderada.
#
# 3. Comparación con otros meses:
#    - Los días sin lluvia (Lluvia = No) son menos frecuentes (4 de 10 registros). Esto refuerza la probabilidad de lluvias en primavera en estos datos.
#
# 4. Datos de lluvia en días específicos:
# ...

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = "SEgún los datos, es más probable que llueva en primavera?"

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4.1-nano",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0.2
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Con base en los datos proporcionados, podemos analizar la probabilidad de lluvia en primavera observando las fechas y las condiciones de lluvia en cada registro.
#
# Observaciones clave:
# - De los 10 registros, 4 muestran que hubo lluvia ese día (marcado como "Lluvia" con valores mayores a 0).
# - Es decir, aproximadamente el 40% de los días en los datos indican lluvia.
# - Los días con lluvias registradas tienen valores de precipitación (Lluvia) que varían desde 2.8 mm hasta 39.8 mm.
# - Los días sin lluvia tienen valores de precipitación cercanos a 0.
#
# Dado que casi la mitad de los días en los datos muestran lluvia, y considerando que estos datos corresponden a días de primavera, podemos inferir que en esta estación hay una probabilidad relativamente alta de que llueva en comparación con otras estaciones o temporadas.
#
# ...

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = "SEgún los datos, es más probable que llueva en primavera?"

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4.1-nano",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0.9
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Con base en los datos proporcionados, podemos analizar la probabilidad de lluvia en primavera observando los patrones en las variables relacionadas con la lluvia.
#
# De los 10 registros:
#
# - 4 datos indican que ha llovido (Lluvia = Yes).
# - 6 datos indican que no ha llovido (Lluvia = No).
#
# Esto significa que aproximadamente el 40% de los días registrados en primavera presentan lluvia, mientras que el 60% no.
#
# Además, si observamos los días específicos en los que hubo lluvia (por ejemplo, los días con valores de "Lluvia" en Yes), notamos que estos días suelen tener niveles de precipitación más altos (por ejemplo, valores cercanos o superiores a 16.2 mm, como 16.2, 39.8, 3.6, 3.6), y también presentan condiciones atmosféricas que favorecen la lluvia, como temperaturas variables y niveles de nubosidad.
#
# Por lo tanto, **en base a estos datos, es más probable que NO llueva en primavera**, ya que la mayoría de los días no presentan precipitaciones.
#
# **Resumen:**
# ...

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = "SEgún los datos, es más probable que llueva en primavera?"

# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# Llamada a la API de OpenAI (ajusta el modelo y cliente según cómo estés usando la API)
response = client.chat.completions.create(
    model="gpt-4o",  # asegúrate de que este sea el modelo correcto disponible para ti
    messages=[
        {"role": "user", "content": prompt}
    ]
)

# Imprime la respuesta
print(response.choices[0].message.content)
# Out:
# Para determinar si es más probable que llueva en primavera, puedes analizar la frecuencia de días con lluvia en los datos proporcionados. Miremos los datos específicos:
#
# De los 10 registros proporcionados:
# - "LluviaHoy" es "Yes" en 5 ocasiones (50%).
# - "LluviaHoy" es "No" en 5 ocasiones (50%).
#
# Por lo tanto, parece que en estos datos específicos para la primavera, hay una probabilidad del 50% de que llueva en un día dado. Sin embargo, estos datos son limitados y puede que no sean representativos de un periodo más amplio o de todas las zonas que presenten un clima templado en primavera. Para obtener conclusiones más precisas, sería ideal contar con una muestra de datos más grande que permita evaluar patrones más relevantes y significativos.

# %% [markdown]
# # Uso de API con Mistral
#
# Documentación en: https://docs.mistral.ai/api/

# %%
import requests
import os
from getpass import getpass

# Asigna tu API key (usa getpass para mayor seguridad en Colab)
os.environ["MISTRAL_API_KEY"] = getpass("Introduce tu Mistral API key: ")

headers = {
    "Authorization": f"Bearer {os.environ['MISTRAL_API_KEY']}",
    "Content-Type": "application/json"
}

data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": "¿Qué es la inteligencia artificial?"}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Introduce tu Mistral API key: ··········
# La inteligencia artificial (IA) es la rama de la computación que se encarga de crear sistemas capaces de imitar o realizar tareas que se asocian con una inteligencia humana. Esto incluye capacidades como aprender, razonar, percibir y tomar decisiones.
#
# Las técnicas de la IA abarcan un amplio espectro de actividades, desde el procesamiento de lenguaje natural hasta la visión por computadora, pasando por la inteligencia artificial cognitive, la inteligencia artificial evolutiva y la inteligencia artificial de aprendizaje profundo.
#
# La IA se utiliza en muchos campos, como la robótica, la medicina, la economía, la ingeniería, la tecnología de la información, la educación y muchos otros. Es una de las disciplinas más importantes y prometedoras en la actualidad, puesto que tiene el potencial de revolucionar muchas áreas de la vida diaria y de la sociedad en general.

# %%
# Convierte una muestra del DataFrame a texto para pasárselo al modelo
df_text = df.tail(10).to_string(index=False)  # puedes ajustar el número de filas

# Captura el input del usuario
user_input = "SEgún los datos, es más probable que llueva en primavera?"

# %%
# Crea el prompt completo
prompt = f"{user_input}\n\nAquí están los datos:\n{df_text}"

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": prompt}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Para determinar si es más probable que llueva en primavera, podemos analizar los datos de la columna "Lluvia" para cada estación de la tabla proporcionada. Se observa que hay 7 casos en que llueve y 6 casos en que no llueve. Por lo tanto, no podemos decir con certeza que sea más probable que llueva en primavera, ya que la distribución de datos no es suficiente para establecer una tendencia clara.
#
# Para una investigación más profunda, podría ser útil analizar datos de una mayor cantidad de estaciones y períodos de tiempo, o incluso utilizar estadísticas para determinar si existe una relación significativa entre la estación del año y la probabilidad de lluvia.

# %%
pregunta = "Puedes analizar los datos de la columna lluviahoy y definir si es probable que llueva el día de hoy?"

# %%
# Crea el prompt completo
new_prompt = f"{pregunta}\n\nAquí están los datos:\n{df_text}"

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": new_prompt}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Para determinar si es probable que llueva el día de hoy, podemos analizar la columna "Lluvia" que indica si llovió o no el día de la medida. En este caso, los datos muestran que solo en un día (el séptimo) se registró lluvia. Por lo tanto, es poco probable que llueva el día de hoy si seguimos el patrón de los datos.
#
# Sin embargo, hay que tener en cuenta que la probabilidad de lluvia puede variar según otros factores meteorológicos que no están registrados en estos datos, como la presión atmosférica, el nivel de humedad o el patrón de vientos. Además, el clima también puede cambiar de manera inesperada, por lo que es posible que haya lluvia en días en los que normalmente no llueve.
#
# En resumen, si basamos nuestra decisión solo en los datos de la columna "Lluvia", es poco probable que llueva el día de hoy, pero si tenemos en cuenta otros factores meteorológicos, la probabilidad puede cambiar.

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": "Puedes inventar la letra de una canción que hable del amor al aprendizaje?"}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# (Verse 1)
#
# In the heart of knowledge, where the curious mind resides,
# A journey through the pages, where the wisdom hides.
# Each book a friend, each word a guide,
# In the world unseen, where the stars collide.
#
# (Chorus)
#
# Oh, the love of learning, my eternal flame,
# The joy that whispers through the pages of the game.
# In the quiet of the night, or the sun's warm beam,
# Life's greatest treasure in every book I dream.
#
# (Verse 2)
#
# From the ancient scrolls to the modern screen,
# A symphony of thoughts, that no one has seen.
# The hours spent pondering, the questions yet unheard,
# The wisdom gained, the knowledge of the universe I've earned.
#
# (Chorus)
#
# Oh, the love of learning, my ceaseless quest,
# The endless journey, with no time to rest.
# In every question, every answer found,
# A deeper truth revealed, a lesson profound.
#
# (Bridge)
#
# So here's to the scholars, the dreamers, the free,
# To those who seek the truth, who dare to see.
# ...

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": "Puedes inventar la letra de una canción en español chileno que hable del amor al aprendizaje?"}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Titulo: Aprendizaje, mi amor
#
# Coro:
# Aprendizaje, mi amor, es lo que me hace vivir,
# Del alma al corazón, me llenas de fuego.
# Nosotros dos juntos, venceremos el miedo,
# Con tus libros y mis notas, siempre estaré contigo.
#
# Verso 1:
# En la escuela, en la calle, en el corazón,
# Tú eres la luz, que brilla en la noche.
# Tú, la sabiduría, que en el alma me alcanzó,
# Con tus enseñanzas, aprendo a soñar.
#
# Coro:
# Aprendizaje, mi amor, es lo que me hace vivir,
# Del alma al corazón, me llenas de fuego.
# Nosotros dos juntos, venceremos el miedo,
# Con tus libros y mis notas, siempre estaré contigo.
#
# Verso 2:
# Tus palabras, son un vuelo, que me lleva al cielo,
# Con tus enseñanzas, aprendo a soñar.
# Tus libros, son una ventana, que me muestran el camino,
# Con tus enseñanzas, aprendo a soñar.
#
# Coro:
# Aprendizaje, mi amor, es lo que me hace vivir,
# Del alma al corazón, me llenas de fuego.
# Nosotros dos juntos, venceremos el miedo,
# ...

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": "Puedes inventar la letra de una canción que hable del amor al aprendizaje de una banda flolk chilena con los acordes de guitarra, por favor?"}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Título: El Amor al Aprendizaje
#
# (Verse 1)
# En un pueblo pequeño bajo el sol brillo,
# Un grupo de amigos con corazón valiente,
# Con guitarras en las manos y canciones en la boca,
# Empiezan a cantar la historia de su lucha.
#
# (Chord: D)
# D                A
# Cantemos a aquellos que buscan saber,
# G                   Bm
# Aprenden con el sol y la luna,
# F                     A
# Sus sueños no se detienen nada,
#          G                      Bm
# Mientras sigan empujando sus límites.
#
# (Verse 2)
# En el corazón de la montaña, a escribir,
# Un nuevo capítulo en la historia,
# Llenos de entusiasmo y desafío,
# Aprendemos cada día algo nuevo.
#
# (Chord: G)
# G                D
# Aprendemos con los maestros y maestras,
# Aprendemos con los libros y las páginas,
# G                D
# Aprendemos para siempre crecer,
# G                D
# Siempre y para siempre aprender.
#
# (Bridge)
# (Chord: A)
# A                   D
# El amor al aprendizaje nos une,
# ...

# %%
import openai
from getpass import getpass

api_key = getpass("Introduce tu clave secreta de OpenAI: ")
client = openai.OpenAI(api_key=api_key)

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", "content": "Puedes inventar la letra de una canción que hable del amor al aprendizaje de una banda flolk chilena con los acordes de guitarra, por favor?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Introduce tu clave secreta de OpenAI: ··········
# Claro, aquí tienes una letra de una canción inspirada en el amor al aprendizaje, al estilo de una banda folk chilena, junto con los acordes de guitarra:
#
# **Título: "Cantos del Saber"**
#
# **Introducción:**
# (C) - (G) - (Am) - (F)
#
# **Verso 1:**
# (C)
# En la patria de (G) libros abiertos,
# (Am)
# caminos de historias que (F) quiero andar.
# (C)
# La tierra me enseña el (G) eco del viento,
# (Am)
# y en cada palabra, (F) vuelvo a empezar.
#
# **Estribillo:**
# (C)
# Cantos del saber, (G) canciones del alma,
# (Am)
# en el folclore hallo (F) mi libertad.
# (C)
# Ríos de letras, (G) versos que abrazan,
# (Am)
# en cada nota, (F) deseo aprender más.
#
# **Verso 2:**
# (C)
# Las estrellas del (G) cielo me guían,
# (Am)
# con susurros suaves de (F) un tiempo sin fin.
# (C)
# El arte es un (G) puente a la sabiduría,
# (Am)
# un mar de colores en el (F) que quiero vivir.
#
# **Estribillo:**
# (C)
# ...

# %%
data = {
    "model": "open-mistral-7b",
    "messages": [
        {"role": "user", "content": "Puedes inventar la letra de una canción que hable del amor al aprendizaje de una banda flolk chilena con los acordes de piano, por favor?"}
    ],
    "temperature": 0.7
}

response = requests.post("https://api.mistral.ai/v1/chat/completions", headers=headers, json=data)

print(response.json()["choices"][0]["message"]["content"])
# Out:
# Título: El Arpa de la Sabiduría
#
# (Verse 1)
# [C] En un pueblo donde el sol se juega,
# [Am] y la luna es el más hermoso espectáculo,
# [F] Habitamos en la sombra de los algarrobo,
# [G] Y aprendemos en el corazón del conocimiento.
#
# (Chorus)
# [C] Siempre tendremos el arpa de la sabiduría,
# [Am] Cantando canciones de luz y de amor,
# [F] Aprendiendo cada día, sin cesar,
# [G] El valioso regalo del conocimiento duradero.
#
# (Verse 2)
# [C] En las páginas de los libros, hallamos nuestros hogares,
# [Am] En la calle de los pensamientos, decoramos nuestro camino,
# [F] Con el viento de las ideas, que nos lleva a los cielos,
# [G] Y con la luz de la sabiduría, que nos ilumina el camino.
#
# (Chorus)
# [C] Siempre tendremos el arpa de la sabiduría,
# [Am] Cantando canciones de luz y de amor,
# [F] Aprendiendo cada día, sin cesar,
# [G] El valioso regalo del conocimiento duradero.
#
# (Bridge)
# [Am] Aprendemos a leer con los ojos del alma,
# ...
